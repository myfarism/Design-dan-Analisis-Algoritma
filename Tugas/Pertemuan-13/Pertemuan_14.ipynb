# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
vertices = range(1, 10)
edges = [(7,2), (2,3), (7,4), (4,5), (7,3), (7,5), (1,6), (1,7), (2,8), (2,9)]

G = nx.Graph()

G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
nx.draw_networkx_nodes(G, pos, nodelist=[1,4,3,8,9], label=True, node_color='g', node_size=1300)
nx.draw_networkx_nodes(G, pos, nodelist=[2,5,6,7], label=True, node_color='r', node_size=1300)
nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')

labels = {}
labels[1]=r'1 NF'
labels[2]=r'2 F'
labels[3]=r'3 NF'
labels[4]=r'4 NF'
labels[5]=r'5 F'
labels[6]=r'6 F'
labels[7]=r'7 F'
labels[8]=r'8 NF'
labels[9]=r'9 NF'


nx.draw_networkx_labels(G, pos, labels, font_size=16)
# Out:
# {1: Text(-0.21433130669186293, 0.6104655088074957, '1 NF'),
#  2: Text(-0.09669811112041792, -0.4730644021972358, '2 F'),
#  3: Text(0.154977902109925, -0.25826603018417793, '3 NF'),
#  4: Text(0.436860400051136, 0.4555423978968467, '4 NF'),
#  5: Text(0.5767737277971617, 0.2219890347916567, '5 F'),
#  6: Text(-0.46671948481806574, 1.0, '6 F'),
#  7: Text(0.12086749005219985, 0.1264162276673109, '7 F'),
#  8: Text(-0.019407627505720882, -0.9486615994177453, '8 NF'),
#  9: Text(-0.49232298987435574, -0.7344211373641518, '9 NF')}

# %%
nx.draw_networkx_nodes(G, pos, nodelist=[1,4,3,8,9], label=True, node_color='g', node_size=1300)
nx.draw_networkx_nodes(G, pos, nodelist=[2,5,6,7], label=True, node_color='r', node_size=1300)
nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')

labels = {}
labels[1]=r'1 NF'
labels[2]=r'2 F'
labels[3]=r'3 NF'
labels[4]=r'4 NF'
labels[5]=r'5 F'
labels[6]=r'6 F'
labels[7]=r'7 F'
labels[8]=r'8 NF'
labels[9]=r'9 NF'

labels = {node: f'{node} ({dos_values[node]})' for node in G.nodes()}

nx.draw_networkx_labels(G, pos, labels, font_size=16)

# Calculate DOS
def cal_dos(node):
  dos = 0
  for neig in G.neighbors(node):
    if labels[neig] != labels[node]:
      dos += 1
  return dos

dos_values = {node: cal_dos(node) for node in G.nodes()}

# %%
vertices = range(1, 10)
edges = [(7,2), (2,3), (7,4), (4,5), (7,3), (7,5), (1,6), (1,7), (2,8), (2,9)]

G = nx.Graph()

G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# Menghitung derajat setiap node
degree_values = dict(G.degree())

# DOS Values
dos_values = {node: degree for node, degree in degree_values.items()}

# Menampilkan DOS Values
print("DOS VALUES")
for node, dos in dos_values.items():
  print(f"{node}: {dos}")

# Normalisasi nilai derajat ke dalam rentang 0-9
max_degree = max(degree_values.values())

# Menghitung DOS values (derajat yang dinormalisasi)
normalized_dos_values = {node: round((degree / max_degree) * 9, 2) for node, degree in degree_values.items()}

# Menampilkan DOS values (derajat yang dinormalisasi)
print("\nNormalized DOS Values:")
for node, normalized_dos in normalized_dos_values.items():
  print(f"{node}: {normalized_dos}")
# Out:
# DOS VALUES
# 1: 2
# 2: 4
# 3: 2
# 4: 2
# 5: 2
# 6: 1
# 7: 5
# 8: 1
# 9: 1
#
# Normalized DOS Values:
# 1: 3.6
# 2: 7.2
# 3: 3.6
# 4: 3.6
# 5: 3.6
# 6: 1.8
# 7: 9.0
# 8: 1.8
# 9: 1.8

# %%
# Latihan 1
vertices1 = range(0, 10)
edges1 = [(1,2), (1,7), (2,3), (2,6), (3,4), (3,6), (6,5), (7,6), (7,8), (7,9), (7,10), (8,9)]

G1 = nx.Graph()

G1.add_nodes_from(vertices1)
G1.add_edges_from(edges1)
pos1 = nx.spring_layout(G1)

nx.draw_networkx_nodes(G1, pos1, nodelist=[1,7,10,4,5], label=True, node_color='r', node_size=1300)
nx.draw_networkx_nodes(G1, pos1, nodelist=[2,3,6,8,9], label=True, node_color='g', node_size=1300)
nx.draw_networkx_edges(G1, pos1, edges1, width=3, alpha=0.5, edge_color='b')

labels1 = {}
labels1[1]=r'1 F'
labels1[2]=r'2 NF'
labels1[3]=r'3 NF'
labels1[4]=r'4 F'
labels1[5]=r'5 F'
labels1[6]=r'6 NF'
labels1[7]=r'7 F'
labels1[8]=r'8 NF'
labels1[9]=r'9 NF'
labels1[10]=r'10 F'


nx.draw_networkx_labels(G1, pos1, labels1, font_size=16)
# Out:
# {1: Text(0.18693068925182577, 0.03796021160042133, '1 F'),
#  2: Text(0.027201463287516534, 0.10522485838038466, '2 NF'),
#  3: Text(-0.12044093811543587, 0.14391747655544698, '3 NF'),
#  4: Text(-0.24539797297031216, 0.28466387736639687, '4 F'),
#  5: Text(-0.15555400178552653, -0.1558543234724381, '5 F'),
#  6: Text(-0.004855741876802298, -0.03824639095168348, '6 NF'),
#  7: Text(0.23922991105216268, -0.13637057032210606, '7 F'),
#  8: Text(0.3696413577751704, -0.27608007950312774, '8 NF'),
#  9: Text(0.2730241406290651, -0.32045222653734157, '9 NF'),
#  10: Text(0.43022109275233644, -0.0890228910266411, '10 F')}

# %%
nx.draw_networkx_nodes(G1, pos1, nodelist=[1,7,10,4,5], label=True, node_color='r', node_size=1300)
nx.draw_networkx_nodes(G1, pos1, nodelist=[2,3,6,8,9], label=True, node_color='g', node_size=1300)
nx.draw_networkx_edges(G1, pos1, edges1, width=3, alpha=0.5, edge_color='b')

labels1 = {}
labels1[1]=r'1 F'
labels1[2]=r'2 NF'
labels1[3]=r'3 NF'
labels1[4]=r'4 F'
labels1[5]=r'5 F'
labels1[6]=r'6 NF'
labels1[7]=r'7 F'
labels1[8]=r'8 NF'
labels1[9]=r'9 NF'
labels1[10]=r'10 F'

labels1 = {node: f'{node} ({dos_values1[node]})' for node in G1.nodes()}

nx.draw_networkx_labels(G1, pos1, labels1, font_size=16)

# Calculate DOS
def cal_dos1(node):
  dos = 0
  for neig in G1.neighbors(node):
    if labels1[neig] != labels1[node]:
      dos += 1
  return dos

dos_values1 = {node: cal_dos1(node) for node in G1.nodes()}

# %%
# Menghitung derajat setiap node
degree_values1 = dict(G1.degree())

# DOS Values
dos_values1 = {node: degree for node, degree in degree_values1.items()}

# Menampilkan DOS Values
print("DOS VALUES")
for node, dos in dos_values1.items():
  print(f"{node}: {dos}")

# Normalisasi nilai derajat ke dalam rentang 0-9
max_degree1 = max(degree_values1.values())

# Menghitung DOS values (derajat yang dinormalisasi)
normalized_dos_values1 = {node: round((degree / max_degree1) * 9, 2) for node, degree in degree_values1.items()}

# Menampilkan DOS values (derajat yang dinormalisasi)
print("\nNormalized DOS Values:")
for node, normalized_dos in normalized_dos_values1.items():
  print(f"{node}: {normalized_dos}")
# Out:
# DOS VALUES
# 0: 0
# 1: 2
# 2: 3
# 3: 3
# 4: 1
# 5: 1
# 6: 4
# 7: 5
# 8: 2
# 9: 2
# 10: 1
#
# Normalized DOS Values:
# 0: 0.0
# 1: 3.6
# 2: 5.4
# 3: 5.4
# 4: 1.8
# 5: 1.8
# 6: 7.2
# 7: 9.0
# 8: 3.6
# 9: 3.6
# 10: 1.8

# %%
# Latihan 2
vertices2 = range(0, 10)
edges2 = [(1,2), (1,3), (2,3), (2,12), (3,4), (4,6), (4,5), (4,7), (7,8), (5,8), (6,9), (8,9), (3,11), (3,10), (11,12), (12,13)]

G2 = nx.Graph()

G2.add_nodes_from(vertices2)
G2.add_edges_from(edges2)
pos2 = nx.spring_layout(G2)

nx.draw_networkx_nodes(G2, pos2, nodelist=[1,2,3,11,10,12], label=True, node_color='r', node_size=1000)
nx.draw_networkx_nodes(G2, pos2, nodelist=[13,4,5,6,7,8,9], label=True, node_color='g', node_size=1000)
nx.draw_networkx_edges(G2, pos2, edges2, width=3, alpha=0.5, edge_color='b')

labels2 = {}
labels2[1]=r'1 F'
labels2[2]=r'2 F'
labels2[3]=r'3 F'
labels2[4]=r'4 NF'
labels2[5]=r'5 NF'
labels2[6]=r'6 NF'
labels2[7]=r'7 NF'
labels2[8]=r'8 NF'
labels2[9]=r'9 NF'
labels2[10]=r'10 F'
labels2[11]=r'11 F'
labels2[12]=r'12 F'
labels2[13]=r'13 NF'


nx.draw_networkx_labels(G2, pos2, labels2, font_size=10)
# Out:
# {1: Text(-0.1766697148091616, 0.2664768924162121, '1 F'),
#  2: Text(-0.25860531133997133, 0.1896414874326434, '2 F'),
#  3: Text(-0.07556572851720188, 0.1529113498998788, '3 F'),
#  4: Text(0.17497858359458224, 0.03863160308188781, '4 NF'),
#  5: Text(0.3058846552563962, -0.0406702640921072, '5 NF'),
#  6: Text(0.3734678912194167, 0.06362451341887577, '6 NF'),
#  7: Text(0.2581776593415787, -0.12133902862723159, '7 NF'),
#  8: Text(0.40696995844441275, -0.1243658876156577, '8 NF'),
#  9: Text(0.5047066550806742, -0.026392625627038518, '9 NF'),
#  10: Text(-0.014655693340634709, 0.3046783259276589, '10 F'),
#  11: Text(-0.2545521009733287, 0.08102849395925293, '11 F'),
#  12: Text(-0.4104506879068631, 0.11575607785982087, '12 F'),
#  13: Text(-0.5748055390621565, 0.1000190619658035, '13 NF')}

# %%
nx.draw_networkx_nodes(G2, pos2, nodelist=[1,2,3,11,10,12], label=True, node_color='r', node_size=1000)
nx.draw_networkx_nodes(G2, pos2, nodelist=[13,4,5,6,7,8,9], label=True, node_color='g', node_size=1000)
nx.draw_networkx_edges(G2, pos2, edges2, width=3, alpha=0.5, edge_color='b')

labels2 = {}
labels2[1]=r'1 F'
labels2[2]=r'2 F'
labels2[3]=r'3 F'
labels2[4]=r'4 NF'
labels2[5]=r'5 NF'
labels2[6]=r'6 NF'
labels2[7]=r'7 NF'
labels2[8]=r'8 NF'
labels2[9]=r'9 NF'
labels2[10]=r'10 F'
labels2[11]=r'11 F'
labels2[12]=r'12 F'
labels2[13]=r'13 NF'

labels2 = {node: f'{node} ({dos_values2[node]})' for node in G2.nodes()}

nx.draw_networkx_labels(G2, pos2, labels2, font_size=10)

# Calculate DOS
def cal_dos2(node):
  dos = 0
  for neig in G2.neighbors(node):
    if labels2[neig] != labels2[node]:
      dos += 1
  return dos

dos_values2 = {node: cal_dos2(node) for node in G2.nodes()}

# %%
# Menghitung derajat setiap node
degree_values2 = dict(G2.degree())

# DOS Values
dos_values2 = {node: degree for node, degree in degree_values2.items()}

# Menampilkan DOS Values
print("DOS VALUES")
for node, dos in dos_values2.items():
  print(f"{node}: {dos}")

# Normalisasi nilai derajat ke dalam rentang 0-9
max_degree2 = max(degree_values2.values())

# Menghitung DOS values (derajat yang dinormalisasi)
normalized_dos_values2 = {node: round((degree / max_degree2) * 9, 2) for node, degree in degree_values2.items()}

# Menampilkan DOS values (derajat yang dinormalisasi)
print("\nNormalized DOS Values:")
for node, normalized_dos in normalized_dos_values2.items():
  print(f"{node}: {normalized_dos}")
# Out:
# DOS VALUES
# 0: 0
# 1: 2
# 2: 3
# 3: 5
# 4: 4
# 5: 2
# 6: 2
# 7: 2
# 8: 3
# 9: 2
# 12: 3
# 11: 2
# 10: 1
# 13: 1
#
# Normalized DOS Values:
# 0: 0.0
# 1: 3.6
# 2: 5.4
# 3: 9.0
# 4: 7.2
# 5: 3.6
# 6: 3.6
# 7: 3.6
# 8: 5.4
# 9: 3.6
# 12: 5.4
# 11: 3.6
# 10: 1.8
# 13: 1.8
